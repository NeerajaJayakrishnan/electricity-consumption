# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import pandas as pd
import pickle
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/Household electricity dataset.csv')
X = df
y = df['Value']




X_complete = X.drop(['Date','Value','Day','day_of_week','Day.1'], axis = 1)


model = LinearRegression()
model.fit(X_complete,y)
#y_pred = model.predict(X_complete)
pickle.dump(model,open("model.pkl","wb"))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model = pickle.load(open("model.pkl", "rb"))
y_pred = model.predict(X_complete)
plt.plot(df['Date'], y_pred, label='Linear Regression')
plt.xlabel('Month')
plt.ylabel('Values (kWh)')
plt.legend()
